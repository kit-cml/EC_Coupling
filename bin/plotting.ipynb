# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("test.csv",header=None)
data
# Out:
#                 0         1
# 0           0.000  0.000000
# 1           0.001  0.000000
# 2           0.002  0.000000
# 3           0.003  0.000000
# 4           0.004  0.000000
# ...           ...       ...
# 999996    999.996  0.000157
# 999997    999.997  0.000157
# 999998    999.998  0.000157
# 999999    999.999  0.000157
# 1000000  1000.000  0.000157
#
# [1000001 rows x 2 columns]

# %%
plt.scatter(data[0],data[1])

# %%
plt.scatter(data[0],data[1]*480)

# %%
data2=pd.read_csv('test_main_paper.csv',header=None)
plt.scatter(data2[0],data2[1], color = 'orange')

# %%
data2
# Out:
#          0         1
# 0        0  0.079191
# 1        1  0.079121
# 2        2  0.079053
# 3        3  0.078984
# 4        4  0.078917
# ...    ...       ...
# 996    996  0.079680
# 997    997  0.079603
# 998    998  0.079526
# 999    999  0.079453
# 1000  1000  0.079380
#
# [1001 rows x 2 columns]

# %%
# Create a figure and subplots with shared x-axis
plt.figure()

# Create scatter plots on each subplot
plt.scatter(data[0], data[1]*480*0.5652016963361872, label='Our Result (x480)', marker='o')
plt.scatter(data2[0], data2[1], color='orange', label='Result from paper (already x480)', marker='s')

# Add labels and title (optional)
plt.ylabel('Force (kilo pascal)')
plt.xlabel('Time (millisecond)')


# Add legend
plt.legend()  # Legend is placed on the top subplot

# Show the plot
plt.tight_layout()
plt.show()

# %%
data2[1][200]
# Out:
# 50.60418087

# %%
data[1][200000]*480
# Out:
# 89.53296

# %%
data2[1][200]/(data[1][200000]*480)
# Out:
# 0.5652016963361872

# %%
#tension comparison
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("test.csv",header=None)
drug = pd.read_csv("../drug.csv")

# Create a figure and subplots with shared x-axis
plt.figure()

# Create scatter plots on each subplot
plt.scatter(data[0], data[1]*480*0.5652016963361872, label='No drug effect', marker='o')
plt.scatter(drug['t'], drug['tension_scaled']*480*0.5652016963361872, color='orange', label='With drug effect', marker='s')

# Add labels and title (optional)
plt.ylabel('Force (kilo pascal)')
plt.xlabel('Time (millisecond)')


# Add legend
plt.legend()  # Legend is placed on the top subplot

# Show the plot
plt.tight_layout()
plt.show()

# %%
#tension comparison
import pandas as pd
import matplotlib.pyplot as plt

# coupled = pd.read_csv("../result/chlorpromazine/0.00/0conc.csv")
ord_only = pd.read_csv("no_contraction.csv")

# Create a figure and subplots with shared x-axis
plt.figure()

# Create scatter plots on each subplot
# plt.scatter(coupled['Time']-198000, coupled['cai'], label='Coupled', marker='o')
plt.scatter(ord_only['Time'], ord_only['Cai'], color='orange', label='No Coupling', marker='s')

# Add labels and title (optional)
# plt.ylabel('Force (kilo pascal)')
# plt.xlabel('Time (millisecond)')


# Add legend
plt.legend()  # Legend is placed on the top subplot

# Show the plot
plt.tight_layout()
plt.show()

# %%
#tension comparison
import pandas as pd
import matplotlib.pyplot as plt

# coupled = pd.read_csv("../result/chlorpromazine/0.00/0conc.csv")
data1 = pd.read_csv("no_contraction.csv")
data2 = pd.read_csv("2000bcl.csv")
data3 = pd.read_csv("1000bcl.csv")
data4 = pd.read_csv("500bcl.csv")

# Create a figure and subplots with shared x-axis
plt.figure()

# Create scatter plots on each subplot
# plt.scatter(coupled['Time']-198000, coupled['cai'], label='Coupled', marker='o')
plt.scatter(data2['Time'], data2['Cai'], color='red', label='2000 BCL', marker='s')
plt.scatter(data1['Time'], data1['Cai'], color='orange', label='1500 BCL', marker='s')
plt.scatter(data3['Time'], data3['Cai'], color='blue', label='1000 BCL', marker='s')
plt.scatter(data4['Time'], data4['Cai'], color='lightblue', label='500 BCL', marker='s')

# Add labels and title (optional)
# plt.ylabel('Force (kilo pascal)')
# plt.xlabel('Time (millisecond)')


# Add legend
plt.legend()  # Legend is placed on the top subplot

# Show the plot
plt.tight_layout()
plt.show()
